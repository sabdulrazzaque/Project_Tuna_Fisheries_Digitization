# %% [markdown]
# Final cleaned version

# %%
import pandas as pd
import panel as pn
import plotly.express as px
import plotly.io as pio

# Set default Plotly theme
pio.templates.default = "plotly_dark"

# Load and preprocess the data
file_path = r'D:\Project_Tuna_Fisheries_Data_Entry\Data\Python\TFDF File Main database_09-12-2024.xlsx'

try:
    data = pd.read_excel(file_path, sheet_name='Sheet1')
except (FileNotFoundError, ValueError):
    print("Error loading data. Falling back to default sample dataset.")
    data = pd.DataFrame({
        'Reg No.': ['A1', 'B2', 'C3'],
        'Year': [2018, 2019, 2020],
        'Total sheets': [10, 20, 30]
    })

# Clean and preprocess the data
if not {'Reg No.', 'Year', 'Total sheets'}.issubset(data.columns):
    raise KeyError("Required columns are missing from the data. Ensure 'Reg No.', 'Year', and 'Total sheets' exist.")

focused_data = data[['Reg No.', 'Year', 'Total sheets']].dropna(subset=['Reg No.', 'Year', 'Total sheets'])
if focused_data.empty:
    raise ValueError("Processed dataset is empty after cleaning. Check the data.")

# Initialize Panel extensions
pn.extension('plotly')

# Define Widgets
reg_selector = pn.widgets.MultiChoice(
    name='Registration Numbers',
    options=list(focused_data['Reg No.'].unique()),
    placeholder="Select Registration Numbers (Optional)"
)
year_selector = pn.widgets.IntRangeSlider(
    name='Year Range',
    start=int(focused_data['Year'].min()),
    end=int(focused_data['Year'].max()),
    value=(int(focused_data['Year'].min()), int(focused_data['Year'].max()))
)
total_sheets_slider = pn.widgets.IntRangeSlider(
    name='Total Sheets Range',
    start=int(focused_data['Total sheets'].min()),
    end=int(focused_data['Total sheets'].max()),
    value=(int(focused_data['Total sheets'].min()), int(focused_data['Total sheets'].max()))
)
theme_toggle = pn.widgets.Toggle(name="Dark Mode", value=True)
reset_button = pn.widgets.Button(name="Reset Filters", button_type="primary")

# Unified Filter Function
_filtered_cache = None  # Cache for filtered data

def invalidate_cache(*events):
    global _filtered_cache
    _filtered_cache = None

def filter_data():
    global _filtered_cache
    if _filtered_cache is not None:
        return _filtered_cache
    filtered = focused_data.copy()
    if reg_selector.value:
        filtered = filtered[filtered['Reg No.'].isin(reg_selector.value)]
    if year_selector.value:
        filtered = filtered[
            (filtered['Year'] >= year_selector.value[0]) & (filtered['Year'] <= year_selector.value[1])
        ]
    if total_sheets_slider.value:
        filtered = filtered[
            (filtered['Total sheets'] >= total_sheets_slider.value[0]) & 
            (filtered['Total sheets'] <= total_sheets_slider.value[1])
        ]
    _filtered_cache = filtered
    return filtered

# Reset filters to default
def reset_filters(event):
    reg_selector.value = []
    year_selector.value = (int(focused_data['Year'].min()), int(focused_data['Year'].max()))
    total_sheets_slider.value = (int(focused_data['Total sheets'].min()), int(focused_data['Total sheets'].max()))
    invalidate_cache()

reset_button.on_click(reset_filters)
reg_selector.param.watch(invalidate_cache, 'value')
year_selector.param.watch(invalidate_cache, 'value')
total_sheets_slider.param.watch(invalidate_cache, 'value')

# Update theme based on toggle
@pn.depends(theme_toggle.param.value, watch=True)
def update_theme(is_dark):
    pio.templates.default = "plotly_dark" if is_dark else "plotly_white"

# KPI Cards
def kpi_card(name, value, description):
    return pn.pane.HTML(
        f"""
        <div style='text-align: center; padding: 10px; border: 1px solid #ccc; border-radius: 10px; background-color: #f9f9f9;'>
            <h3 style='margin: 5px;'>{name}</h3>
            <p style='font-size: 24px; margin: 5px; font-weight: bold;'>{value}</p>
            <p style='font-size: 12px; margin: 5px; color: #555;'>{description}</p>
        </div>
        """,
        width=200
    )

# Display KPIs
@pn.depends(reg_selector.param.value, year_selector.param.value, total_sheets_slider.param.value)
def display_kpis(reg_numbers, year_range, sheets_range):
    filtered = filter_data()

    if filtered.empty:
        return pn.pane.Markdown("### No data matches the selected filters. Please adjust the filters.", style={"color": "red"})

    total_registrations = filtered['Reg No.'].nunique()
    total_sheets = filtered['Total sheets'].sum()
    avg_sheets = filtered['Total sheets'].mean()
    median_sheets = filtered['Total sheets'].median()
    max_sheets = filtered['Total sheets'].max()
    std_dev_sheets = filtered['Total sheets'].std()

    return pn.Row(
        kpi_card("Total Registrations", total_registrations, "Unique registrations in the filtered data"),
        kpi_card("Total Sheets", total_sheets, "Sum of all sheets in the filtered data"),
        kpi_card("Avg Sheets/Reg", f"{avg_sheets:.2f}", "Average sheets per registration"),
        kpi_card("Median Sheets/Reg", f"{median_sheets:.2f}", "Median of sheets per registration"),
        kpi_card("Max Sheets/Reg", max_sheets, "Maximum sheets by a single registration"),
        kpi_card("Std Dev Sheets", f"{std_dev_sheets:.2f}", "Standard deviation of sheets")
    )

# Create Charts
@pn.depends(reg_selector.param.value, year_selector.param.value, total_sheets_slider.param.value)
def create_charts(reg_numbers, year_range, sheets_range):
    filtered = filter_data()

    if filtered.empty:
        return pn.pane.Markdown("### No data available for the selected filters.", style={"color": "red"})

    charts = []
    charts.append(pn.pane.Plotly(px.scatter(
        filtered, x='Year', y='Total sheets', color='Reg No.',
        size='Total sheets', title='Scatter Plot: Total Sheets vs Year',
        trendline='ols', height=500, width=800
    )))
    charts.append(pn.pane.Plotly(px.histogram(
        filtered, x='Total sheets', nbins=20,
        title='Histogram: Distribution of Total Sheets',
        height=500, width=800
    )))
    charts.append(pn.pane.Plotly(px.bar(
        filtered, x='Reg No.', y='Total sheets', color='Year',
        title='Bar Chart: Total Sheets by Registration Number',
        height=500, width=800
    )))
    charts.append(pn.pane.Plotly(px.line(
        filtered.groupby('Year')['Total sheets'].sum().reset_index(),
        x='Year', y='Total sheets',
        title='Line Chart: Total Sheets Over Time',
        height=500, width=800
    )))
    charts.append(pn.pane.Plotly(px.box(
        filtered, x='Year', y='Total sheets', color='Reg No.',
        title='Box Plot: Total Sheets Distribution by Year',
        height=500, width=800
    )))
    heatmap_data = filtered.pivot_table(
        index='Reg No.', columns='Year', values='Total sheets', aggfunc='sum', fill_value=0
    )
    charts.append(pn.pane.Plotly(px.imshow(
        heatmap_data, title='Heatmap: Total Sheets by Year and Registration Number',
        color_continuous_scale='Viridis', height=500, width=800
    )))
    cumulative_data = filtered.sort_values(by='Year')
    cumulative_data['Cumulative Sheets'] = cumulative_data['Total sheets'].cumsum()
    charts.append(pn.pane.Plotly(px.line(
        cumulative_data, x='Year', y='Cumulative Sheets',
        title='Cumulative Sheets Over Time',
        height=500, width=800
    )))
    return pn.Column(*charts)

# Dashboard Layout
instructions = pn.pane.Markdown(
    "### Instructions\n1. Use filters to narrow down data.\n2. Explore visualizations in real time.\n3. Reset filters for default view.\n\n### Troubleshooting\n- If no data appears, try resetting the filters.\n- Ensure the dataset is loaded correctly and contains the required columns."
)

dashboard = pn.Column(
    pn.pane.Markdown("# Interactive Dashboard: Total Sheets Analysis"),
    instructions,
    pn.Row(
        pn.Column(reg_selector),
        pn.Column(year_selector),
        pn.Column(total_sheets_slider),
        pn.Column(theme_toggle),
        pn.Column(reset_button),
    ),
    display_kpis,
    create_charts
)

# Serve the Dashboard
dashboard.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b797da7c-ecbe-4bec-aa88-83d84d6613f4'>
#   <div id="fd7f4768-a586-48a2-b3a1-841fe01efd0e" data-root-id="b797da7c-ecbe-4bec-aa88-83d84d6613f4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d51c28cf-6b2a-4783-8f53-1e9d63fc6ab7":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"b797da7c-ecbe-4bec-aa88-83d84d6613f4"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"302fa6d9-d6ab-4b29-9645-2f2efb8245dc","attributes":{"plot_id":"b797da7c-ecbe-4bec-aa88-83d84d6613f4","comm_id":"6687329305ae401fb09bf475fc3389af","client_comm_id":"b67bad3df02d4083a83d49b0b938ba66"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"d51c28cf-6b2a-4783-8f53-1e9d63fc6ab7","roots":{"b797da7c-ecbe-4bec-aa88-83d84d6613f4":"fd7f4768-a586-48a2-b3a1-841fe01efd0e"},"root_ids":["b797da7c-ecbe-4bec-aa88-83d84d6613f4"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=2,level=1,tokens=9), 2, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=2,level=1,tokens=9), 2, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=2,level=1,tokens=9), 2, 8, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=3,level=1,tokens=14), 3, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=3,level=1,tokens=14), 3, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=3,level=1,tokens=14), 3, 8, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=5,level=1,tokens=19), 5, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=5,level=1,tokens=19), 5, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=5,level=1,tokens=19), 5, 8, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=7,level=1,tokens=29), 7, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=7,level=1,tokens=29), 7, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=7,level=1,tokens=29), 7, 8, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# BokehModel(combine_events=True, render_bundle={'docs_json': {'b243ae9a-22dc-440f-af9b-737b136219aa': {'version…
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 50, 20000, tzinfo=tzutc()), 'msg_id': '3f19a86e-aa3a-4d3a-bc43-0ccc052739bb', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '3f19a86e-aa3a-4d3a-bc43-0ccc052739bb', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'update', 'state': {'_view_count': 1}, 'buffer_paths': []}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 50, 848000, tzinfo=tzutc()), 'msg_id': 'a7485574-6741-4416-a39b-22355cd3a30c', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'a7485574-6741-4416-a39b-22355cd3a30c', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '420f709a-cb41-482a-955a-d63a9698882c'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2011.384398876443, 2019.6248593517316]], ['yaxis.range', [-2.599706517610569, 58.026929568462165]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 52, 522000, tzinfo=tzutc()), 'msg_id': '3339141a-fa0f-40d2-bc3f-e5df48ef2914', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '3339141a-fa0f-40d2-bc3f-e5df48ef2914', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '64a48861-190e-4303-ac4d-a199956ff7d7'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [-0.5, 54.5]], ['yaxis.range', [0, 154.73684210526315]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 52, 524000, tzinfo=tzutc()), 'msg_id': '2c19883b-69f1-415a-8b75-24c714d2ca3b', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '2c19883b-69f1-415a-8b75-24c714d2ca3b', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '396d4bfe-f9a5-4d44-be5e-3259a6cec46f'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2012, 2019]], ['yaxis.range', [-1.6666666666666572, 3511.6666666666665]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 52, 629000, tzinfo=tzutc()), 'msg_id': 'bf192895-494a-43d5-b94f-e32b5933353f', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'bf192895-494a-43d5-b94f-e32b5933353f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': 'ed984a4b-46c8-46a9-b1ca-c48830facb24'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2011.4583333333333, 2019.5416666666667]], ['yaxis.range', [-1.8333333333333335, 54.833333333333336]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 52, 830000, tzinfo=tzutc()), 'msg_id': 'e4182e79-07aa-4721-90ba-4965a256a42c', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'e4182e79-07aa-4721-90ba-4965a256a42c', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '72eb5d1d-a453-467a-a69a-b0525e964d12'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2012, 2019]], ['yaxis.range', [-692.5555555555555, 14018.555555555555]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 52, 831000, tzinfo=tzutc()), 'msg_id': 'd46bcb47-0798-4192-b990-194cd880747c', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'd46bcb47-0798-4192-b990-194cd880747c', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': 'a0507bd1-2b70-403c-80e9-7b813ee7f80f'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [-0.5, 61.5]], ['yaxis.range', [0, 1594.7368421052631]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 52, 952000, tzinfo=tzutc()), 'msg_id': '82c328fa-3f45-4448-8655-c28f317e4fdb', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '82c328fa-3f45-4448-8655-c28f317e4fdb', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '1d05e56b-3651-4865-9713-42d4a1ae747c'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2011.5, 2019.5]], ['yaxis.range', [61.5, -0.5]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 52, 956000, tzinfo=tzutc()), 'msg_id': 'e2a1fc2a-3751-4ca1-b723-b4d4e5ad8838', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'e2a1fc2a-3751-4ca1-b723-b4d4e5ad8838', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '420f709a-cb41-482a-955a-d63a9698882c'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 53, 86000, tzinfo=tzutc()), 'msg_id': '0706ef0e-99d6-4c22-bfea-bd53afdf7b05', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '0706ef0e-99d6-4c22-bfea-bd53afdf7b05', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '64a48861-190e-4303-ac4d-a199956ff7d7'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 53, 96000, tzinfo=tzutc()), 'msg_id': '4a033bed-f7b2-402f-8273-f1c688991a50', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '4a033bed-f7b2-402f-8273-f1c688991a50', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '396d4bfe-f9a5-4d44-be5e-3259a6cec46f'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 53, 250000, tzinfo=tzutc()), 'msg_id': 'e3977cf9-3a1b-4045-a859-3f7d2b2bb347', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'e3977cf9-3a1b-4045-a859-3f7d2b2bb347', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': 'ed984a4b-46c8-46a9-b1ca-c48830facb24'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 53, 398000, tzinfo=tzutc()), 'msg_id': 'b6eba8a6-d995-4131-a026-86bdbac733ee', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'b6eba8a6-d995-4131-a026-86bdbac733ee', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '72eb5d1d-a453-467a-a69a-b0525e964d12'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 53, 425000, tzinfo=tzutc()), 'msg_id': '2fdc5d9e-dcaa-481f-b360-c55aabb6d4eb', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '2fdc5d9e-dcaa-481f-b360-c55aabb6d4eb', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': 'a0507bd1-2b70-403c-80e9-7b813ee7f80f'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 53, 506000, tzinfo=tzutc()), 'msg_id': 'e74f6225-6d73-4bc1-86c5-1e1b5ac4a4b5', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'e74f6225-6d73-4bc1-86c5-1e1b5ac4a4b5', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '1d05e56b-3651-4865-9713-42d4a1ae747c'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d76b3cea50854e3ba95829b221558ad2]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 53, 631000, tzinfo=tzutc()), 'msg_id': '87208a0d-a147-42e0-b139-e9edbcac4a01', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '87208a0d-a147-42e0-b139-e9edbcac4a01', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd76b3cea50854e3ba95829b221558ad2', 'data': {'method': 'custom', 'content': {'kind': 'MessageSent', 'msg_type': 'bokeh_event', 'msg_data': {'type': 'event', 'name': 'document_ready', 'values': {'type': 'map'}}, 'event': 'jsevent'}}}, 'buffers': []})

# %% [markdown]
# with Debug

# %%
import pandas as pd
import panel as pn
import plotly.express as px
import plotly.io as pio
import logging

# Initialize logging
logging.basicConfig(level=logging.DEBUG)

# Set default Plotly theme
pio.templates.default = "plotly_dark"

# Load and preprocess the data
file_path = r'D:\Project_Tuna_Fisheries_Data_Entry\Data\Python\TFDF File Main database_09-12-2024.xlsx'

try:
    data = pd.read_excel(file_path, sheet_name='Sheet1')
except (FileNotFoundError, ValueError):
    print("Error loading data. Falling back to sample dataset for demonstration purposes.")
    data = pd.DataFrame({
        'Reg No.': ['A1', 'B2', 'C3'],
        'Year': [2018, 2019, 2020],
        'Total sheets': [10, 20, 30]
    })

# Validate columns
required_columns = {'Reg No.', 'Year', 'Total sheets'}
if not required_columns.issubset(data.columns):
    raise KeyError(f"Required columns are missing: {required_columns - set(data.columns)}.")

focused_data = data[['Reg No.', 'Year', 'Total sheets']].dropna(subset=required_columns)
if focused_data.empty:
    raise ValueError("Processed dataset is empty after cleaning. Check the data.")

# Initialize Panel extensions
pn.extension('plotly')

# Define Widgets
reg_selector = pn.widgets.MultiChoice(
    name='Registration Numbers',
    options=list(focused_data['Reg No.'].unique()),
    placeholder="Select Registration Numbers (Optional)"
)
year_selector = pn.widgets.IntRangeSlider(
    name='Year Range',
    start=int(focused_data['Year'].min()),
    end=int(focused_data['Year'].max()),
    value=(int(focused_data['Year'].min()), int(focused_data['Year'].max()))
)
total_sheets_slider = pn.widgets.IntRangeSlider(
    name='Total Sheets Range',
    start=int(focused_data['Total sheets'].min()),
    end=int(focused_data['Total sheets'].max()),
    value=(int(focused_data['Total sheets'].min()), int(focused_data['Total sheets'].max()))
)
theme_toggle = pn.widgets.Toggle(name="Dark Mode", value=True)
reset_button = pn.widgets.Button(name="Reset Filters", button_type="primary")

# Cache for filtered data
_filtered_cache = None

def invalidate_cache(*events):
    global _filtered_cache
    _filtered_cache = None

def filter_data():
    global _filtered_cache
    if _filtered_cache is not None:
        return _filtered_cache
    filtered = focused_data.copy()
    if reg_selector.value:
        filtered = filtered[filtered['Reg No.'].isin(reg_selector.value)]
    if year_selector.value:
        filtered = filtered[
            (filtered['Year'] >= year_selector.value[0]) & (filtered['Year'] <= year_selector.value[1])
        ]
    if total_sheets_slider.value:
        filtered = filtered[
            (filtered['Total sheets'] >= total_sheets_slider.value[0]) &
            (filtered['Total sheets'] <= total_sheets_slider.value[1])
        ]
    _filtered_cache = filtered
    return filtered

# Reset filters
def reset_filters(event):
    reg_selector.value = []
    year_selector.value = (focused_data['Year'].min(), focused_data['Year'].max())
    total_sheets_slider.value = (focused_data['Total sheets'].min(), focused_data['Total sheets'].max())
    invalidate_cache()

reset_button.on_click(reset_filters)
reg_selector.param.watch(invalidate_cache, 'value')
year_selector.param.watch(invalidate_cache, 'value')
total_sheets_slider.param.watch(invalidate_cache, 'value')

# Update theme
@pn.depends(theme_toggle.param.value, watch=True)
def update_theme(is_dark):
    pio.templates.default = "plotly_dark" if is_dark else "plotly_white"

# KPI Cards
def kpi_card(name, value, description):
    return pn.pane.HTML(
        f"""
        <div style='text-align: center; padding: 10px; border: 1px solid #ccc; border-radius: 10px; background-color: #f9f9f9;'>
            <h3 style='margin: 5px;'>{name}</h3>
            <p style='font-size: 24px; margin: 5px; font-weight: bold;'>{value}</p>
            <p style='font-size: 12px; margin: 5px; color: #555;'>{description}</p>
        </div>
        """,
        width=200
    )

# Display KPIs
@pn.depends(reg_selector.param.value, year_selector.param.value, total_sheets_slider.param.value)
def display_kpis(reg_numbers, year_range, sheets_range):
    filtered = filter_data()

    if filtered.empty:
        return pn.pane.Markdown("### No data matches the selected filters. Please adjust the filters.", style={"color": "red"})

    total_registrations = filtered['Reg No.'].nunique()
    total_sheets = filtered['Total sheets'].sum()
    avg_sheets = filtered['Total sheets'].mean()
    median_sheets = filtered['Total sheets'].median()
    max_sheets = filtered['Total sheets'].max()
    std_dev_sheets = filtered['Total sheets'].std()

    return pn.Row(
        kpi_card("Total Registrations", total_registrations, "Unique registrations in the filtered data"),
        kpi_card("Total Sheets", total_sheets, "Sum of all sheets in the filtered data"),
        kpi_card("Avg Sheets/Reg", f"{avg_sheets:.2f}", "Average sheets per registration"),
        kpi_card("Median Sheets/Reg", f"{median_sheets:.2f}", "Median of sheets per registration"),
        kpi_card("Max Sheets/Reg", max_sheets, "Maximum sheets by a single registration"),
        kpi_card("Std Dev Sheets", f"{std_dev_sheets:.2f}", "Standard deviation of sheets")
    )

# Create Charts
@pn.depends(reg_selector.param.value, year_selector.param.value, total_sheets_slider.param.value)
def create_charts(reg_numbers, year_range, sheets_range):
    filtered = filter_data()
    if filtered.empty:
        return pn.pane.Markdown(
            f"### No data available for the selected filters:\n"
            f"- Registration Numbers: {', '.join(reg_selector.value) or 'All'}\n"
            f"- Year Range: {year_selector.value}\n"
            f"- Total Sheets Range: {total_sheets_slider.value}",
            style={"color": "red"}
        )

    # Regenerate charts dynamically
    charts = []
    charts.append(pn.pane.Plotly(px.scatter(
        filtered, x='Year', y='Total sheets', color='Reg No.',
        size='Total sheets', title='Scatter Plot: Total Sheets vs Year',
        trendline='ols', height=500, width=800
    )))
    charts.append(pn.pane.Plotly(px.histogram(
        filtered, x='Total sheets', nbins=20,
        title='Histogram: Distribution of Total Sheets',
        height=500, width=800
    )))
    charts.append(pn.pane.Plotly(px.bar(
        filtered, x='Reg No.', y='Total sheets', color='Year',
        title='Bar Chart: Total Sheets by Registration Number',
        height=500, width=800
    )))
    charts.append(pn.pane.Plotly(px.line(
        filtered.groupby('Year')['Total sheets'].sum().reset_index(),
        x='Year', y='Total sheets',
        title='Line Chart: Total Sheets Over Time',
        height=500, width=800
    )))
    charts.append(pn.pane.Plotly(px.box(
        filtered, x='Year', y='Total sheets', color='Reg No.',
        title='Box Plot: Total Sheets Distribution by Year',
        height=500, width=800
    )))
    heatmap_data = filtered.pivot_table(
        index='Reg No.', columns='Year', values='Total sheets', aggfunc='sum', fill_value=0
    )
    charts.append(pn.pane.Plotly(px.imshow(
        heatmap_data, title='Heatmap: Total Sheets by Year and Registration Number',
        color_continuous_scale='Viridis', height=500, width=800
    )))
    cumulative_data = filtered.sort_values(by='Year')
    cumulative_data['Cumulative Sheets'] = cumulative_data['Total sheets'].cumsum()
    charts.append(pn.pane.Plotly(px.line(
        cumulative_data, x='Year', y='Cumulative Sheets',
        title='Cumulative Sheets Over Time',
        height=500, width=800
    )))
    return pn.Column(*charts)

# Dashboard Layout
instructions = pn.pane.Markdown(
    "### Instructions\n1. Use filters to narrow down data.\n2. Explore visualizations in real time.\n3. Reset filters for default view.\n\n### Troubleshooting\n- If no data appears, try resetting the filters.\n- Ensure the dataset is loaded correctly and contains the required columns."
)

dashboard = pn.Column(
    pn.pane.Markdown("# Interactive Dashboard: Total Sheets Analysis"),
    instructions,
    pn.Row(
        pn.Column(reg_selector),
        pn.Column(year_selector),
        pn.Column(total_sheets_slider),
        pn.Column(theme_toggle),
        pn.Column(reset_button),
    ),
    display_kpis,
    create_charts
)

# Serve the Dashboard
dashboard.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4507ed10-f1cb-4ba5-86c1-e39007d965ee'>
#   <div id="b32b98ff-b38b-491a-b095-17e614fac133" data-root-id="4507ed10-f1cb-4ba5-86c1-e39007d965ee" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"34b1d7a6-eb2b-4f77-855c-5db6c5abe8ce":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"4507ed10-f1cb-4ba5-86c1-e39007d965ee"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"e3378cd6-71a0-44f3-8993-973363272bd7","attributes":{"plot_id":"4507ed10-f1cb-4ba5-86c1-e39007d965ee","comm_id":"873ea9a3258e41949d36f784cd2d2bda","client_comm_id":"743cf2f808b2470a8c2fb3172a9f2456"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"34b1d7a6-eb2b-4f77-855c-5db6c5abe8ce","roots":{"4507ed10-f1cb-4ba5-86c1-e39007d965ee":"b32b98ff-b38b-491a-b095-17e614fac133"},"root_ids":["4507ed10-f1cb-4ba5-86c1-e39007d965ee"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=0,level=0,tokens=0), 0, 8, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=0,tokens=3), 1, 8, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=1,level=2,tokens=5), 1, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=2,tokens=5), 2, 8, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=2,level=1,tokens=9), 2, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=2,level=1,tokens=9), 2, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=2,level=1,tokens=9), 2, 8, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=2,level=2,tokens=10), 2, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=2,level=2,tokens=10), 3, 8, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=3,level=1,tokens=14), 3, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=3,level=1,tokens=14), 3, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=3,level=1,tokens=14), 3, 8, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=3,level=2,tokens=15), 3, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=5,level=1,tokens=19), 5, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=5,level=1,tokens=19), 5, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=5,level=1,tokens=19), 5, 8, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=5,level=0,tokens=20), 5, 8, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=0,tokens=23), 6, 8, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=6,level=2,tokens=25), 6, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=2,tokens=25), 7, 8, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=7,level=1,tokens=29), 7, 8, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=7,level=1,tokens=29), 7, 8, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=7,level=1,tokens=29), 7, 8, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=7,level=2,tokens=30), 7, 8, False
# BokehModel(combine_events=True, render_bundle={'docs_json': {'23b982d1-d11d-4292-92c4-7ada7b174ee9': {'version…
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 29, 437000, tzinfo=tzutc()), 'msg_id': '1e80312b-5e61-4a8f-8b3c-049f7f207419', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '1e80312b-5e61-4a8f-8b3c-049f7f207419', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'update', 'state': {'_view_count': 1}, 'buffer_paths': []}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 30, 295000, tzinfo=tzutc()), 'msg_id': '59c37ee9-8ab4-4528-b413-5150f068575b', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '59c37ee9-8ab4-4528-b413-5150f068575b', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '76a21d04-7ec1-47b7-8100-734bc879dc5c'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2011.384398876443, 2019.6248593517316]], ['yaxis.range', [-2.599706517610569, 58.026929568462165]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 67000, tzinfo=tzutc()), 'msg_id': '3369a86a-e0d5-47ec-bab4-3c0af6e85de3', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '3369a86a-e0d5-47ec-bab4-3c0af6e85de3', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': 'a42a987c-d107-472b-aa92-f62b3610d45f'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [-0.5, 54.5]], ['yaxis.range', [0, 154.73684210526315]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 75000, tzinfo=tzutc()), 'msg_id': '1db32fea-440d-43df-ad5e-242a9d743e4c', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '1db32fea-440d-43df-ad5e-242a9d743e4c', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '4e208c37-fcca-414a-8f24-2260d51ffa7f'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2012, 2019]], ['yaxis.range', [-1.6666666666666572, 3511.6666666666665]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 170000, tzinfo=tzutc()), 'msg_id': 'd45cc54d-3fb5-4527-a4b8-a43e6b3ebd0d', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'd45cc54d-3fb5-4527-a4b8-a43e6b3ebd0d', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '5feb8639-5dcb-4a85-83fb-54e9595ba569'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2011.4583333333333, 2019.5416666666667]], ['yaxis.range', [-1.8333333333333335, 54.833333333333336]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 178000, tzinfo=tzutc()), 'msg_id': 'f4e0fe5e-1e5b-47bf-b969-d56e829b49f8', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'f4e0fe5e-1e5b-47bf-b969-d56e829b49f8', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '37948a4d-2a67-4fae-91e2-02d785d8a3b2'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2012, 2019]], ['yaxis.range', [-692.5555555555555, 14018.555555555555]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 372000, tzinfo=tzutc()), 'msg_id': 'e153c123-6499-42d2-84f4-9a1c43552373', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'e153c123-6499-42d2-84f4-9a1c43552373', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '05fa83bd-a8ac-409f-9822-8579452a4c4a'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [-0.5, 61.5]], ['yaxis.range', [0, 1594.7368421052631]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 381000, tzinfo=tzutc()), 'msg_id': '4e814f81-22ce-4395-a589-554899fdf251', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '4e814f81-22ce-4395-a589-554899fdf251', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': 'f56eabe4-5f22-44b5-ad32-d582a6281dfe'}, 'attr': 'viewport', 'new': {'type': 'map', 'entries': [['xaxis.range', [2011.5, 2019.5]], ['yaxis.range', [61.5, -0.5]]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 493000, tzinfo=tzutc()), 'msg_id': '1d4c3256-5395-4b23-bab2-c3d243decdeb', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '1d4c3256-5395-4b23-bab2-c3d243decdeb', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '76a21d04-7ec1-47b7-8100-734bc879dc5c'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 531000, tzinfo=tzutc()), 'msg_id': '641cab77-09b6-426e-89b3-a7b89e39fd18', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '641cab77-09b6-426e-89b3-a7b89e39fd18', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': 'a42a987c-d107-472b-aa92-f62b3610d45f'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 653000, tzinfo=tzutc()), 'msg_id': '4b79e036-4f60-4cf0-80c1-4472747684b3', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '4b79e036-4f60-4cf0-80c1-4472747684b3', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '4e208c37-fcca-414a-8f24-2260d51ffa7f'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 680000, tzinfo=tzutc()), 'msg_id': 'f70c50b8-f5ed-4218-bd81-04784cd7a9f0', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'f70c50b8-f5ed-4218-bd81-04784cd7a9f0', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '5feb8639-5dcb-4a85-83fb-54e9595ba569'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 805000, tzinfo=tzutc()), 'msg_id': 'e79dbc93-9019-44dc-9442-5f1fa477ae2e', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'e79dbc93-9019-44dc-9442-5f1fa477ae2e', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '37948a4d-2a67-4fae-91e2-02d785d8a3b2'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 815000, tzinfo=tzutc()), 'msg_id': 'f023ee89-5f01-43bc-8a8e-dceab085f2b3', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'f023ee89-5f01-43bc-8a8e-dceab085f2b3', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': '05fa83bd-a8ac-409f-9822-8579452a4c4a'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 925000, tzinfo=tzutc()), 'msg_id': 'e0131904-380c-4d6c-9f3b-a3adc0aca153', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': 'e0131904-380c-4d6c-9f3b-a3adc0aca153', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'ModelChanged', 'model': {'id': 'f56eabe4-5f22-44b5-ad32-d582a6281dfe'}, 'attr': 'relayout_data', 'new': {'type': 'map', 'entries': [['width', 800], ['height', 500]]}, 'event': 'jsevent'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d6bc21e7277c41b8b73013ebe6df32b5]({'header': {'date': datetime.datetime(2024, 12, 13, 10, 8, 32, 990000, tzinfo=tzutc()), 'msg_id': '8ce1833a-053f-46e0-b753-dec3a606dbba', 'msg_type': 'comm_msg', 'session': '5fa71421-42a4-41f8-98d4-424506e73710', 'username': '6f4d10e5-9cd5-4a46-a24a-bd39b051fa64', 'version': '5.2'}, 'msg_id': '8ce1833a-053f-46e0-b753-dec3a606dbba', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd6bc21e7277c41b8b73013ebe6df32b5', 'data': {'method': 'custom', 'content': {'kind': 'MessageSent', 'msg_type': 'bokeh_event', 'msg_data': {'type': 'event', 'name': 'document_ready', 'values': {'type': 'map'}}, 'event': 'jsevent'}}}, 'buffers': []})
